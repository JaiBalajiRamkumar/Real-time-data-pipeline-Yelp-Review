# %%
# !pip install elasticsearch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.0/654.0 kB 11.0 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from elasticsearch import Elasticsearch, helpers
import json

# Connect to Elasticsearch Cloud
client = Elasticsearch(
    "https://yelp-review-deployment.es.us-east-2.aws.elastic-cloud.com",
    verify_certs=False,
    basic_auth=("elastic", "kT4a9iAONgV2jzkQwjmeBc7J")
)

# Open the file and read json object
with open("/kaggle/input/yelp-dataset/yelp_academic_dataset_business.json") as f:
    data = []
    for line in f:
        try:
            doc = json.loads(line.strip())
            data.append(doc)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            
    helpers.bulk(client, data, index="business_data_index")
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'yelp-review-deployment.es.us-east-2.aws.elastic-cloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'yelp-review-deployment.es.us-east-2.aws.elastic-cloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
